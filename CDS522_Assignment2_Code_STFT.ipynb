# %% [markdown]
# # CDS522 Text and Speech Analytics
# ## Assignment 2 - A Comparison Between LSTM and RNN on Speech Recognition Using TensorFlow
# | Name | Matrix No. |
# | ---| --- |
# | Gan Zhong Li | P-COM0156/21 |
# | Tang Eva | P-COM0179/21 |

# %%
import os
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display

# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

from sklearn.metrics import classification_report

# %% [markdown]
# ## Import the mini Speech Commands dataset

# %%
DATASET_PATH = 'data/mini_speech_commands'

data_dir = pathlib.Path(DATASET_PATH)
if not data_dir.exists():
  tf.keras.utils.get_file(
      'mini_speech_commands.zip',
      origin="http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip",
      extract=True,
      cache_dir='.', cache_subdir='data')

# %% [markdown]
# The dataset's audio clips are stored in eight folders corresponding to each speech command: `no`, `yes`, `down`, `go`, `left`, `up`, `right`, and `stop`:

# %%
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
commands = commands[commands != 'README.md']
print('Commands:', commands)
# Out:
# Commands: ['down' 'go' 'left' 'no' 'right' 'stop' 'up' 'yes']

# %% [markdown]
# Loading the data using `keras.utils.audio_dataset_from_directory`.
#
# The audio clips are 1 second or less at 16kHz. The `output_sequence_length=16000` pads the short ones to exactly 1 second.

# %%
train_ds, val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=data_dir,
    batch_size=64,
    validation_split=0.2,
    seed=0,
    output_sequence_length=16000,
    subset='both')

label_names = np.array(train_ds.class_names)
print()
print("label names:", label_names)
# Out:
# Found 8000 files belonging to 8 classes.
# Using 6400 files for training.
# Using 1600 files for validation.
#
# label names: ['down' 'go' 'left' 'no' 'right' 'stop' 'up' 'yes']

# %% [markdown]
# The dataset contains batches of audio clips and integer labels. The audio clips have a shape of `(batch, samples, channels)`.

# %%
train_ds.element_spec
# Out:
# (TensorSpec(shape=(None, 16000, None), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None,), dtype=tf.int32, name=None))

# %% [markdown]
# This dataset only contains single channel audio, `tf.squeeze` function is used to drop the extra axis:

# %%
def squeeze(audio, labels):
  audio = tf.squeeze(audio, axis=-1)
  return audio, labels

train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
val_ds = val_ds.map(squeeze, tf.data.AUTOTUNE)

# %%
train_ds.element_spec
# Out:
# (TensorSpec(shape=(None, 16000), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None,), dtype=tf.int32, name=None))

# %% [markdown]
# Using `Dataset.shard` function to split the validation set into two halves.

# %%
test_ds = val_ds.shard(num_shards=2, index=0)
val_ds = val_ds.shard(num_shards=2, index=1)

# %%
for example_audio, example_labels in train_ds.take(1):  
  print(example_audio.shape)
  print(example_labels.shape)
# Out:
# (64, 16000)
# (64,)

# %% [markdown]
# Let's plot a few audio waveforms:

# %%
label_names[[1,1,3,0]]
# Out:
# array(['go', 'go', 'no', 'down'], dtype='<U5')

# %%
rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(16, 9))

for i in range(n):
  if i>=n:
    break
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  ax.plot(example_audio[i].numpy())
  ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
  label = label_names[example_labels[i]]
  ax.set_title(label)
  ax.set_ylim([-1.1,1.1])

plt.show()

# %% [markdown]
# ## Convert waveforms to spectrograms using STFT
#
# A function is created to transform waveforms to spectrograms using `tf.signal.stft`

# %%
def get_spectrogram(waveform):
  # Convert the waveform to a spectrogram via a STFT.
  spectrogram = tf.signal.stft(
      waveform, frame_length=255, frame_step=128)
  # Obtain the magnitude of the STFT.
  spectrogram = tf.abs(spectrogram)
  # Add a `channels` dimension, so that the spectrogram can be used
  # as image-like input data with convolution layers (which expect
  # shape (`batch_size`, `height`, `width`, `channels`).
  # spectrogram = spectrogram[..., tf.newaxis]
  return spectrogram

# %% [markdown]
# Next, start exploring the data. Print the shapes of one example's tensorized waveform and the corresponding spectrogram, and play the original audio:

# %%
for i in range(3):
  label = label_names[example_labels[i]]
  waveform = example_audio[i]
  spectrogram = get_spectrogram(waveform)

  print('Label:', label)
  print('Waveform shape:', waveform.shape)
  print('Spectrogram shape:', spectrogram.shape)
  print('Audio playback')
  display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: go
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: no
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: left
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Plotting the spectogram spectrogram:

# %%
def plot_spectrogram(spectrogram, ax):
  if len(spectrogram.shape) > 2:
    assert len(spectrogram.shape) == 3
    spectrogram = np.squeeze(spectrogram, axis=-1)
  # Convert the frequencies to log scale and transpose, so that the time is
  # represented on the x-axis (columns).
  # Add an epsilon to avoid taking a log of zero.
  log_spec = np.log(spectrogram.T + np.finfo(float).eps)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)

fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.suptitle(label.title())
plt.show()

# %% [markdown]
# Now, create spectrogramn datasets from the audio datasets:

# %%
def make_spec_ds(ds):
  return ds.map(
      map_func=lambda audio,label: (get_spectrogram(audio), label),
      num_parallel_calls=tf.data.AUTOTUNE)

train_spectrogram_ds = make_spec_ds(train_ds)
val_spectrogram_ds = make_spec_ds(val_ds)
test_spectrogram_ds = make_spec_ds(test_ds)
# Out:
# WARNING:tensorflow:From c:\Users\SVC-MLDEV.SERVICE\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# Examine the spectrograms for different examples of the dataset:

# %%
for example_spectrograms, example_spect_labels in train_spectrogram_ds.take(1):
  break

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(16, 9))

for i in range(n):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    plot_spectrogram(example_spectrograms[i].numpy(), ax)
    ax.set_title(commands[example_spect_labels[i].numpy()])

plt.show()

# %% [markdown]
# ## Build and train the model

# %% [markdown]
# Add `Dataset.cache` and `Dataset.prefetch` operations to reduce read latency while training the model:

# %%
train_spectrogram_ds = train_spectrogram_ds.cache().shuffle(10000).prefetch(tf.data.AUTOTUNE)
val_spectrogram_ds = val_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)
test_spectrogram_ds = test_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### LSTM Model

# %%
input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
num_labels = len(commands)

# Instantiate the `tf.keras.layers.Normalization` layer.
norm_layer = layers.Normalization()
# Fit the state of the layer to the spectrograms
# with `Normalization.adapt`.
norm_layer.adapt(data=train_spectrogram_ds.map(map_func=lambda spec, label: spec))

model = models.Sequential([
    layers.Input(shape=input_shape),
    # Normalize.
    norm_layer,
    layers.LSTM(128, input_shape=input_shape),
    layers.Dropout(0.1),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(16, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(num_labels),
])

model.summary()
# Out:
# Input shape: (124, 129)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 124, 129)         259
#  n)
#
#  lstm (LSTM)                 (None, 128)               132096
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dropout_4 (Dropout)         (None, 16)                0
#
#  dense_4 (Dense)             (None, 8)                 136
#
# =================================================================
# Total params: 159,867
# Trainable params: 159,608
# Non-trainable params: 259
# _________________________________________________________________

# %% [markdown]
# Configure the Keras model with the Adam optimizer and the cross-entropy loss:

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# Train the model over 10 epochs for demonstration purposes:

# %%
EPOCHS = 100
history = model.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    # callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=5),
)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 30s 270ms/step - loss: 2.0275 - accuracy: 0.1814 - val_loss: 1.9828 - val_accuracy: 0.1758
# Epoch 2/100
# 100/100 [==============================] - 25s 253ms/step - loss: 1.9670 - accuracy: 0.2023 - val_loss: 1.9584 - val_accuracy: 0.1849
# Epoch 3/100
# 100/100 [==============================] - 26s 257ms/step - loss: 1.9914 - accuracy: 0.1873 - val_loss: 1.9973 - val_accuracy: 0.1706
# Epoch 4/100
# 100/100 [==============================] - 25s 250ms/step - loss: 1.9661 - accuracy: 0.1856 - val_loss: 1.9591 - val_accuracy: 0.1706
# Epoch 5/100
# 100/100 [==============================] - 26s 258ms/step - loss: 1.9576 - accuracy: 0.1848 - val_loss: 1.8273 - val_accuracy: 0.2109
# Epoch 6/100
# 100/100 [==============================] - 27s 273ms/step - loss: 1.7856 - accuracy: 0.2466 - val_loss: 1.6821 - val_accuracy: 0.2891
# Epoch 7/100
# 100/100 [==============================] - 27s 270ms/step - loss: 1.6310 - accuracy: 0.2945 - val_loss: 1.7250 - val_accuracy: 0.3151
# Epoch 8/100
# 100/100 [==============================] - 26s 262ms/step - loss: 1.5644 - accuracy: 0.3398 - val_loss: 1.4845 - val_accuracy: 0.3802
# Epoch 9/100
# 100/100 [==============================] - 27s 274ms/step - loss: 1.4396 - accuracy: 0.3852 - val_loss: 1.3928 - val_accuracy: 0.4089
# Epoch 10/100
# 100/100 [==============================] - 27s 272ms/step - loss: 1.3705 - accuracy: 0.4008 - val_loss: 1.3428 - val_accuracy: 0.4180
# Epoch 11/100
# 100/100 [==============================] - 27s 270ms/step - loss: 1.2830 - accuracy: 0.4330 - val_loss: 1.2750 - val_accuracy: 0.4245
# Epoch 12/100
# 100/100 [==============================] - 27s 271ms/step - loss: 1.1939 - accuracy: 0.4875 - val_loss: 1.1604 - val_accuracy: 0.5260
# Epoch 13/100
# 100/100 [==============================] - 27s 268ms/step - loss: 1.0894 - accuracy: 0.5512 - val_loss: 1.0618 - val_accuracy: 0.5508
# Epoch 14/100
# 100/100 [==============================] - 27s 269ms/step - loss: 0.9975 - accuracy: 0.5792 - val_loss: 0.9919 - val_accuracy: 0.5885
# Epoch 15/100
# 100/100 [==============================] - 29s 286ms/step - loss: 0.9076 - accuracy: 0.6078 - val_loss: 0.9189 - val_accuracy: 0.6107
# 100/100 [==============================] - 19s 186ms/step - loss: 0.1219 - accuracy: 0.9613 - val_loss: 0.5888 - val_accuracy: 0.8854
# Epoch 94/100
# 100/100 [==============================] - 18s 179ms/step - loss: 0.1171 - accuracy: 0.9627 - val_loss: 0.6502 - val_accuracy: 0.8932
# Epoch 95/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.1046 - accuracy: 0.9664 - val_loss: 0.6010 - val_accuracy: 0.8893
# Epoch 96/100
# 100/100 [==============================] - 19s 190ms/step - loss: 0.1067 - accuracy: 0.9659 - val_loss: 0.6163 - val_accuracy: 0.8867
# Epoch 97/100
# 100/100 [==============================] - 18s 185ms/step - loss: 0.1191 - accuracy: 0.9623 - val_loss: 0.6321 - val_accuracy: 0.8802
# Epoch 98/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.0989 - accuracy: 0.9677 - val_loss: 0.6523 - val_accuracy: 0.8919
# Epoch 99/100
# 100/100 [==============================] - 19s 187ms/step - loss: 0.0959 - accuracy: 0.9686 - val_loss: 0.5962 - val_accuracy: 0.8789
# Epoch 100/100
# 100/100 [==============================] - 18s 184ms/step - loss: 0.1043 - accuracy: 0.9666 - val_loss: 0.6129 - val_accuracy: 0.8880

# %% [markdown]
# Let's plot the training and validation loss curves to check how your model has improved during training:

# %%
metrics = history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ## Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
model.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 13/13 [==============================] - 1s 64ms/step - loss: 0.4501 - accuracy: 0.9099
# {'loss': 0.4500707983970642, 'accuracy': 0.9098557829856873}

# %% [markdown]
# ### Display a confusion matrix

# %%
y_pred = model.predict(test_spectrogram_ds)
# Out:
# 13/13 [==============================] - 1s 43ms/step

# %%
y_pred = tf.argmax(y_pred, axis=1)

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# #### Performance metrics

# %%
# Accuracy
m = tf.keras.metrics.Accuracy()

m.update_state(y_true, y_pred)

print(f"Accuracy: {m.result().numpy()}")
# Out:
# Accuracy: 0.9098557829856873

# %%
# Precision, recall and F1-score
print(classification_report(y_true, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8991    0.8991    0.8991       109
#            1     0.8148    0.8800    0.8462       100
#            2     0.9057    0.8889    0.8972       108
#            3     0.9271    0.8476    0.8856       105
#            4     0.9630    0.9176    0.9398        85
#            5     0.9469    0.9640    0.9554       111
#            6     0.8991    0.9515    0.9245       103
#            7     0.9364    0.9279    0.9321       111
#
#     accuracy                         0.9099       832
#    macro avg     0.9115    0.9096    0.9100       832
# weighted avg     0.9112    0.9099    0.9100       832

# %% [markdown]
# ### RNN

# %%
input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
num_labels = len(commands)

# Instantiate the `tf.keras.layers.Normalization` layer.
norm_layer = layers.Normalization()
# Fit the state of the layer to the spectrograms
# with `Normalization.adapt`.
norm_layer.adapt(data=train_spectrogram_ds.map(map_func=lambda spec, label: spec))

rnn_model = models.Sequential([
    layers.Input(shape=input_shape),
    # Normalize.
    norm_layer,
    layers.SimpleRNN(256, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(16, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(num_labels),
])

rnn_model.summary()
# Out:
# Input shape: (124, 129)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_1 (Normalizat  (None, 124, 129)         259
#  ion)
#
#  simple_rnn (SimpleRNN)      (None, 256)               98816
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 16)                528
#
#  dropout_9 (Dropout)         (None, 16)                0
#
#  dense_9 (Dense)             (None, 8)                 136
#
# =================================================================
# Total params: 142,971
# Trainable params: 142,712
# Non-trainable params: 259
# _________________________________________________________________

# %% [markdown]
# Configure the Keras model with the Adam optimizer and the cross-entropy loss:

# %%
rnn_model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# Train the model over 10 epochs for demonstration purposes:

# %%
EPOCHS = 100

rnn_history = rnn_model.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    # callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=5),
)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 9s 67ms/step - loss: 2.0677 - accuracy: 0.1398 - val_loss: 2.0739 - val_accuracy: 0.1432
# Epoch 2/100
# 100/100 [==============================] - 7s 65ms/step - loss: 2.0962 - accuracy: 0.1327 - val_loss: 2.0789 - val_accuracy: 0.1237
# Epoch 3/100
# 100/100 [==============================] - 7s 69ms/step - loss: 2.0665 - accuracy: 0.1531 - val_loss: 2.1025 - val_accuracy: 0.1302

# %% [markdown]
# Let's plot the training and validation loss curves to check how your model has improved during training:

# %%
rnn_metrics = rnn_history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(rnn_history.epoch, rnn_metrics['loss'], rnn_metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(rnn_history.epoch, 100*np.array(rnn_metrics['accuracy']), 100*np.array(rnn_metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ## Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
rnn_model.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 13/13 [==============================] - 0s 25ms/step - loss: 2.0727 - accuracy: 0.1130
# {'loss': 2.072721242904663, 'accuracy': 0.11298076808452606}

# %% [markdown]
# ### Display a confusion matrix

# %%
rnn_y_pred = rnn_model.predict(test_spectrogram_ds)
# Out:
# 13/13 [==============================] - 0s 22ms/step

# %%
rnn_y_pred = tf.argmax(rnn_y_pred, axis=1)

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
rnn_confusion_mtx = tf.math.confusion_matrix(y_true, rnn_y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(rnn_confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# #### Performance metric

# %%
# Accuracy
m = tf.keras.metrics.Accuracy()

m.update_state(y_true, rnn_y_pred)

print(f"Accuracy: {m.result().numpy()}")
# Out:
# Accuracy: 0.11298076808452606

# %%
# Precision, recall and F1-score
print(classification_report(y_true, rnn_y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.5000    0.0183    0.0354       109
#            1     0.0952    0.0400    0.0563       100
#            2     0.0000    0.0000    0.0000       108
#            3     0.0000    0.0000    0.0000       105
#            4     0.0979    0.8588    0.1757        85
#            5     0.0000    0.0000    0.0000       111
#            6     0.0000    0.0000    0.0000       103
#            7     0.5000    0.1351    0.2128       111
#
#     accuracy                         0.1130       832
#    macro avg     0.1491    0.1315    0.0600       832
# weighted avg     0.1537    0.1130    0.0577       832
# c:\Users\SVC-MLDEV.SERVICE\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\SVC-MLDEV.SERVICE\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\SVC-MLDEV.SERVICE\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
